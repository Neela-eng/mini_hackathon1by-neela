# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !pip install ipython-sql

# %load_ext sql
import sqlite3
conn = sqlite3.connect('database.db')

# %sql sqlite:///database.db
import pandas as pd
movie=pd.read_csv("/kaggle/input/imdb-dataset-of-top-1000-movies-and-tv-shows/imdb_top_1000.csv")
movie.to_sql('movie', conn, if_exists='replace', index=False)
# Out:
# ...
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# 1000

# %%
# %%sql
#    select * from movie;
# Out:
#  * sqlite:///database.db
# Done.
# [('https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_UX67_CR0,0,67,98_AL_.jpg', 'The Shawshank Redemption', '1994', 'A', '142 min', 'Drama', 9.3, 'Two imprisoned men bond over a number of years, finding solace and eventual redemption through acts of common decency.', 80.0, 'Frank Darabont', 'Tim Robbins', 'Morgan Freeman', 'Bob Gunton', 'William Sadler', 2343110, '28,341,469'),
#  ('https://m.media-amazon.com/images/M/MV5BM2MyNjYxNmUtYTAwNi00MTYxLWJmNWYtYzZlODY3ZTk3OTFlXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_UY98_CR1,0,67,98_AL_.jpg', 'The Godfather', '1972', 'A', '175 min', 'Crime, Drama', 9.2, "An organized crime dynasty's aging patriarch transfers control of his clandestine empire to his reluctant son.", 100.0, 'Francis Ford Coppola', 'Marlon Brando', 'Al Pacino', 'James Caan', 'Diane Keaton', 1620367, '134,966,411'),
# ...

# %%
# %%sql
#    select distinct Director,Series_Title,Gross from movie order by Gross;
# Out:
#  * sqlite:///database.db
# Done.
# [('Thomas Kail', 'Hamilton', None),
#  ('Sudha Kongara', 'Soorarai Pottru', None),
#  ('Masaki Kobayashi', 'Seppuku', None),
#  ('Frank Capra', "It's a Wonderful Life", None),
#  ('Isao Takahata', 'Hotaru no haka', None),
#  ('Can Ulkay', 'Ayla: The Daughter of War', None),
#  ('Gayatri', 'Vikram Vedha', None),
#  ('Hrishikesh Mukherjee', 'Anand', None),
#  ('Akira Kurosawa', 'Tengoku to jigoku', None),
#  ('Stanley Kubrick', 'Paths of Glory', None),
#  ('Billy Wilder', 'Sunset Blvd.', None),
#  ('Rahi Anil Barve', 'Tumbbad', None),
#  ('Jeethu Joseph', 'Drishyam', None),
#  ('Mehmet Ada Öztekin', 'Miracle in cell NO.7', None),
#  ('Çagan Irmak', 'Babam ve Oglum', None),
#  ('Elem Klimov', 'Idi i smotri', None),
#  ('Prashanth Neel', 'K.G.F: Chapter 1', None),
#  ('Sergio Pablos', 'Klaus', None),
#  ('Anurag Kashyap', 'Gangs of Wasseypur', None),
#  ('Priyadarshan', 'Hera Pheri', None),
#  ('Yavuz Turgul', 'Eskiya', None),
# ...

# %%
# %%sql
#   select  Director, Series_Title,max(Gross) from movie;
# Out:
#  * sqlite:///database.db
# Done.
# [('Imtiaz Ali', 'Rockstar', '985,912')]

# %%
# %%sql
#  select Director ,Series_Title,Gross from movie where Director = "Imtiaz Ali";
# Out:
#  * sqlite:///database.db
# Done.
# [('Imtiaz Ali', 'Jab We Met', '410,800'),
#  ('Imtiaz Ali', 'Rockstar', '985,912')]

# %%
# %%sql
#  select Director ,Series_Title,min(Gross) from movie;
# Out:
#  * sqlite:///database.db
# Done.
# [("Shin'ichirô Watanabe", 'Cowboy Bebop: Tengoku no tobira', '1,000,045')]

# %%
# %%sql
#  select Director,count(Series_Title) from movie group by Director;
# Out:
#  * sqlite:///database.db
# Done.
# [('Aamir Khan', 1),
#  ('Aaron Sorkin', 1),
#  ('Abdellatif Kechiche', 1),
#  ('Abhishek Chaubey', 1),
#  ('Abhishek Kapoor', 1),
#  ('Adam Elliot', 1),
#  ('Adam McKay', 1),
#  ('Aditya Chopra', 1),
#  ('Aditya Dhar', 1),
#  ('Akira Kurosawa', 10),
#  ('Alain Resnais', 1),
#  ('Alan J. Pakula', 1),
#  ('Alan Parker', 3),
#  ('Alejandro Amenábar', 3),
#  ('Alejandro G. Iñárritu', 4),
#  ('Alejandro Jodorowsky', 1),
#  ('Alex Garland', 1),
#  ('Alex Proyas', 1),
#  ('Alexander Mackendrick', 2),
#  ('Alexander Payne', 1),
#  ('Alfonso Cuarón', 6),
#  ('Alfonso Gomez-Rejon', 1),
#  ('Alfred Hitchcock', 14),
#  ('Amit Ravindernath Sharma', 1),
#  ('Anders Thomas Jensen', 1),
#  ('Andrei Tarkovsky', 5),
#  ('Andrew Adamson', 1),
#  ('Andrew Davis', 1),
#  ('Andrew Lau', 1),
#  ('Andrew Niccol', 2),
#  ('Andrew Stanton', 2),
#  ('Andrey Zvyagintsev', 3),
#  ('Aneesh Chaganty', 1),
#  ('Ang Lee', 4),
#  ('Aniruddha Roy Chowdhury', 1),
# ...

# %%
# %%sql
#    select Director,count(Series_Title) as total_movies, sum(Gross) as Sum_gross from movie group by Director order by Sum_gross;
# Out:
#  * sqlite:///database.db
# Done.
# [('Aaron Sorkin', 1, None),
#  ('Abhishek Chaubey', 1, None),
#  ('Adam Elliot', 1, None),
#  ('Aditya Chopra', 1, None),
#  ('Alexander Mackendrick', 2, None),
#  ('Amit Ravindernath Sharma', 1, None),
#  ('Arthur Penn', 1, None),
#  ('Blake Edwards', 1, None),
#  ('Bob Gale', 1, None),
#  ('Can Ulkay', 1, None),
#  ('Charles Vidor', 1, None),
#  ('Cy Endfield', 1, None),
#  ('Daniel Monzón', 1, None),
#  ('Darius Marder', 1, None),
#  ('Dennis Gansel', 1, None),
#  ('Elem Klimov', 1, None),
#  ('Ericson Core', 1, None),
#  ('François Truffaut', 2, None),
#  ('Gayatri', 1, None),
#  ('George Sluizer', 1, None),
#  ('George Stevens', 1, None),
#  ('Henri-Georges Clouzot', 2, None),
#  ('Henry Koster', 1, None),
#  ('Hideaki Anno', 1, None),
#  ('Hong-jin Na', 1, None),
#  ('Hrishikesh Mukherjee', 1, None),
#  ('J. Lee Thompson', 1, None),
#  ('Jacques Tourneur', 1, None),
#  ('Jae-young Kwak', 1, None),
#  ('Jeethu Joseph', 1, None),
# ...

# %%
# %%sql
#     select Genre,Released_Year,Gross from movie;
# Out:
#  * sqlite:///database.db
# Done.
# [('Drama', '1994', '28,341,469'),
#  ('Crime, Drama', '1972', '134,966,411'),
#  ('Action, Crime, Drama', '2008', '534,858,444'),
#  ('Crime, Drama', '1974', '57,300,000'),
#  ('Crime, Drama', '1957', '4,360,000'),
#  ('Action, Adventure, Drama', '2003', '377,845,905'),
#  ('Crime, Drama', '1994', '107,928,762'),
#  ('Biography, Drama, History', '1993', '96,898,818'),
#  ('Action, Adventure, Sci-Fi', '2010', '292,576,195'),
#  ('Drama', '1999', '37,030,102'),
#  ('Action, Adventure, Drama', '2001', '315,544,750'),
#  ('Drama, Romance', '1994', '330,252,182'),
#  ('Western', '1966', '6,100,000'),
#  ('Action, Adventure, Drama', '2002', '342,551,365'),
#  ('Action, Sci-Fi', '1999', '171,479,930'),
#  ('Biography, Crime, Drama', '1990', '46,836,394'),
#  ('Action, Adventure, Fantasy', '1980', '290,475,067'),
#  ('Drama', '1975', '112,000,000'),
#  ('Biography, Drama, History', '2020', None),
#  ('Comedy, Drama, Thriller', '2019', '53,367,844'),
# ...

# %%
# %%sql
#     select Genre,Released_Year,max(Gross) as highest_Gross from movie;
# Out:
#  * sqlite:///database.db
# Done.
# [('Drama, Music, Musical', '2011', '985,912')]

# %%
# %%sql
#     select Genre,Released_Year,Gross from movie where Released_Year>2000;
# Out:
#  * sqlite:///database.db
# Done.
# [('Action, Crime, Drama', '2008', '534,858,444'),
#  ('Action, Adventure, Drama', '2003', '377,845,905'),
#  ('Action, Adventure, Sci-Fi', '2010', '292,576,195'),
#  ('Action, Adventure, Drama', '2001', '315,544,750'),
#  ('Action, Adventure, Drama', '2002', '342,551,365'),
#  ('Biography, Drama, History', '2020', None),
#  ('Comedy, Drama, Thriller', '2019', '53,367,844'),
#  ('Drama', '2020', None),
#  ('Adventure, Drama, Sci-Fi', '2014', '188,020,017'),
#  ('Crime, Drama', '2002', '7,563,397'),
#  ('Animation, Adventure, Family', '2001', '10,055,859'),
#  ('Crime, Drama, Thriller', '2019', '335,451,311'),
#  ('Drama, Music', '2014', '13,092,000'),
#  ('Biography, Comedy, Drama', '2011', '13,182,281'),
#  ('Drama, Mystery, Sci-Fi', '2006', '53,089,891'),
#  ('Crime, Drama, Thriller', '2006', '132,384,315'),
#  ('Biography, Drama, Music', '2002', '32,572,577'),
#  ('Drama', '2018', '1,661,096'),
#  ('Biography, Drama, History', '2017', None),
# ...

# %%
# %%sql
#     select Genre,Released_Year,Gross from movie where Released_Year<2000;
# Out:
#  * sqlite:///database.db
# Done.
# [('Drama', '1994', '28,341,469'),
#  ('Crime, Drama', '1972', '134,966,411'),
#  ('Crime, Drama', '1974', '57,300,000'),
#  ('Crime, Drama', '1957', '4,360,000'),
#  ('Crime, Drama', '1994', '107,928,762'),
#  ('Biography, Drama, History', '1993', '96,898,818'),
#  ('Drama', '1999', '37,030,102'),
#  ('Drama, Romance', '1994', '330,252,182'),
#  ('Western', '1966', '6,100,000'),
#  ('Action, Sci-Fi', '1999', '171,479,930'),
#  ('Biography, Crime, Drama', '1990', '46,836,394'),
#  ('Action, Adventure, Fantasy', '1980', '290,475,067'),
#  ('Drama', '1975', '112,000,000'),
#  ('Drama, War', '1998', '216,540,909'),
#  ('Crime, Drama, Fantasy', '1999', '136,801,374'),
#  ('Comedy, Drama, Romance', '1997', '57,598,247'),
#  ('Crime, Drama, Mystery', '1995', '100,125,643'),
#  ('Crime, Drama, Thriller', '1991', '130,742,922'),
#  ('Action, Adventure, Fantasy', '1977', '322,740,140'),
#  ('Action, Drama, Mystery', '1962', None),
# ...

# %%
# %%sql
#    select Series_Title,IMDB_Rating ,Gross from movie order by IMDB_Rating;
# Out:
#  * sqlite:///database.db
# Done.
# [('Dark Waters', 7.6, None),
#  ('Searching', 7.6, '26,020,957'),
#  ('Once Upon a Time... in Hollywood', 7.6, '142,502,728'),
#  ('Nelyubov', 7.6, '566,356'),
#  ('The Florida Project', 7.6, '5,904,366'),
#  ('Just Mercy', 7.6, None),
#  ('Gifted', 7.6, '24,801,212'),
#  ('The Peanut Butter Falcon', 7.6, '13,122,642'),
#  ('Victoria', 7.6, None),
#  ('Mustang', 7.6, '845,464'),
#  ('Guardians of the Galaxy Vol. 2', 7.6, '389,813,101'),
#  ('Baby Driver', 7.6, '107,825,862'),
#  ('Only the Brave', 7.6, '18,340,051'),
#  ('Bridge of Spies', 7.6, '72,313,754'),
#  ('Incredibles 2', 7.6, '608,581,744'),
#  ('Moana', 7.6, '248,757,044'),
#  ('Sicario', 7.6, '46,889,293'),
#  ('Creed', 7.6, '109,767,581'),
#  ('Leviafan', 7.6, '1,092,800'),
#  ('Hell or High Water', 7.6, '26,862,450'),
#  ('Philomena', 7.6, '37,707,719'),
#  ('Dawn of the Planet of the Apes', 7.6, '208,545,589'),
#  ('El cuerpo', 7.6, None),
#  ('Serbuan maut', 7.6, '4,105,123'),
# ...

# %%
# %%sql
#   select Series_Title,IMDB_Rating,max(Gross) as Hightest_gross from movie;
# Out:
#  * sqlite:///database.db
# Done.
# [('Rockstar', 7.7, '985,912')]

# %%
# %%sql
#   select Series_Title,MAX(IMDB_Rating) as hightest_rating,Gross  from movie;
# Out:
#  * sqlite:///database.db
# Done.
# [('The Shawshank Redemption', 9.3, '28,341,469')]

# %%
# %%sql
#     select Series_Title,IMDB_Rating,Gross, case when IMDB_Rating >8.5 and Gross>800000  then 'Excellent' when IMDB_Rating Between 8  and 9 and Gross Between 750000 and 850000 then 'VeryGood' when IMDB_Rating Between 8 and 9 and Gross>850000 then "Very Good"  when IMDB_Rating>9 and Gross>5000000 then "Good" when IMDB_Rating>9 and Gross Between 750000 and 850000 then "Very Good"  when IMDB_Rating>8 and Gross<500000 then"Good at Rating" when IMDB_Rating<8 and Gross>500000 then "Good at profit" when IMDB_Rating<8 and Gross<500000 then "Average"  end as status from movie;
# Out:
#  * sqlite:///database.db
# Done.
# [('The Shawshank Redemption', 9.3, '28,341,469', 'Good at Rating'),
#  ('The Godfather', 9.2, '134,966,411', 'Good at Rating'),
#  ('The Dark Knight', 9.0, '534,858,444', None),
#  ('The Godfather: Part II', 9.0, '57,300,000', None),
#  ('12 Angry Men', 9.0, '4,360,000', 'Good at Rating'),
#  ('The Lord of the Rings: The Return of the King', 8.9, '377,845,905', 'Good at Rating'),
#  ('Pulp Fiction', 8.9, '107,928,762', 'Good at Rating'),
#  ("Schindler's List", 8.9, '96,898,818', 'Excellent'),
#  ('Inception', 8.8, '292,576,195', 'Good at Rating'),
#  ('Fight Club', 8.8, '37,030,102', 'Good at Rating'),
#  ('The Lord of the Rings: The Fellowship of the Ring', 8.8, '315,544,750', 'Good at Rating'),
#  ('Forrest Gump', 8.8, '330,252,182', 'Good at Rating'),
#  ('Il buono, il brutto, il cattivo', 8.8, '6,100,000', None),
#  ('The Lord of the Rings: The Two Towers', 8.7, '342,551,365', 'Good at Rating'),
# ...

# %%
# %%sql
#   select Series_Title,Runtime,IMDB_Rating,Gross from movie;
# Out:
#  * sqlite:///database.db
# Done.
# [('The Shawshank Redemption', '142 min', 9.3, '28,341,469'),
#  ('The Godfather', '175 min', 9.2, '134,966,411'),
#  ('The Dark Knight', '152 min', 9.0, '534,858,444'),
#  ('The Godfather: Part II', '202 min', 9.0, '57,300,000'),
#  ('12 Angry Men', '96 min', 9.0, '4,360,000'),
#  ('The Lord of the Rings: The Return of the King', '201 min', 8.9, '377,845,905'),
#  ('Pulp Fiction', '154 min', 8.9, '107,928,762'),
#  ("Schindler's List", '195 min', 8.9, '96,898,818'),
#  ('Inception', '148 min', 8.8, '292,576,195'),
#  ('Fight Club', '139 min', 8.8, '37,030,102'),
#  ('The Lord of the Rings: The Fellowship of the Ring', '178 min', 8.8, '315,544,750'),
#  ('Forrest Gump', '142 min', 8.8, '330,252,182'),
#  ('Il buono, il brutto, il cattivo', '161 min', 8.8, '6,100,000'),
#  ('The Lord of the Rings: The Two Towers', '179 min', 8.7, '342,551,365'),
#  ('The Matrix', '136 min', 8.7, '171,479,930'),
#  ('Goodfellas', '146 min', 8.7, '46,836,394'),
# ...

# %%
# %%sql
#   select Series_Title,Runtime,Max(IMDB_Rating) as highest_rating,Gross from movie;
# Out:
#  * sqlite:///database.db
# Done.
# [('The Shawshank Redemption', '142 min', 9.3, '28,341,469')]

# %%
# %%sql
#   select Series_Title,Runtime,IMDB_Rating,max(Gross) as Highest_gross from movie;
# Out:
#  * sqlite:///database.db
# Done.
# [('Rockstar', '159 min', 7.7, '985,912')]

# %%
# %%sql
#   select Series_Title,min(Runtime),IMDB_Rating,Gross from movie;
# Out:
#  * sqlite:///database.db
# Done.
# [('Soul', '100 min', 8.1, None)]

# %%
# %%sql
#   select Series_Title,Star1,Star2, Star3,Star4 ,IMDB_Rating,Gross from movie;
# Out:
#  * sqlite:///database.db
# Done.
# [('The Shawshank Redemption', 'Tim Robbins', 'Morgan Freeman', 'Bob Gunton', 'William Sadler', 9.3, '28,341,469'),
#  ('The Godfather', 'Marlon Brando', 'Al Pacino', 'James Caan', 'Diane Keaton', 9.2, '134,966,411'),
#  ('The Dark Knight', 'Christian Bale', 'Heath Ledger', 'Aaron Eckhart', 'Michael Caine', 9.0, '534,858,444'),
#  ('The Godfather: Part II', 'Al Pacino', 'Robert De Niro', 'Robert Duvall', 'Diane Keaton', 9.0, '57,300,000'),
#  ('12 Angry Men', 'Henry Fonda', 'Lee J. Cobb', 'Martin Balsam', 'John Fiedler', 9.0, '4,360,000'),
#  ('The Lord of the Rings: The Return of the King', 'Elijah Wood', 'Viggo Mortensen', 'Ian McKellen', 'Orlando Bloom', 8.9, '377,845,905'),
#  ('Pulp Fiction', 'John Travolta', 'Uma Thurman', 'Samuel L. Jackson', 'Bruce Willis', 8.9, '107,928,762'),
#  ("Schindler's List", 'Liam Neeson', 'Ralph Fiennes', 'Ben Kingsley', 'Caroline Goodall', 8.9, '96,898,818'),
# ...

# %%
# %%sql
#    select Series_Title,Released_Year, IMDB_Rating,Gross from movie;
# Out:
#  * sqlite:///database.db
# Done.
# [('The Shawshank Redemption', '1994', 9.3, '28,341,469'),
#  ('The Godfather', '1972', 9.2, '134,966,411'),
#  ('The Dark Knight', '2008', 9.0, '534,858,444'),
#  ('The Godfather: Part II', '1974', 9.0, '57,300,000'),
#  ('12 Angry Men', '1957', 9.0, '4,360,000'),
#  ('The Lord of the Rings: The Return of the King', '2003', 8.9, '377,845,905'),
#  ('Pulp Fiction', '1994', 8.9, '107,928,762'),
#  ("Schindler's List", '1993', 8.9, '96,898,818'),
#  ('Inception', '2010', 8.8, '292,576,195'),
#  ('Fight Club', '1999', 8.8, '37,030,102'),
#  ('The Lord of the Rings: The Fellowship of the Ring', '2001', 8.8, '315,544,750'),
#  ('Forrest Gump', '1994', 8.8, '330,252,182'),
#  ('Il buono, il brutto, il cattivo', '1966', 8.8, '6,100,000'),
#  ('The Lord of the Rings: The Two Towers', '2002', 8.7, '342,551,365'),
#  ('The Matrix', '1999', 8.7, '171,479,930'),
#  ('Goodfellas', '1990', 8.7, '46,836,394'),
# ...

# %%
# %%sql
#    select Series_Title,Released_Year, IMDB_Rating,max(Gross) from movie;
# Out:
#  * sqlite:///database.db
# Done.
# [('Rockstar', '2011', 7.7, '985,912')]

# %%
# %%sql
#    select Series_Title,Released_Year, IMDB_Rating,Gross from movie where Released_year>2000;
# Out:
#  * sqlite:///database.db
# Done.
# [('The Dark Knight', '2008', 9.0, '534,858,444'),
#  ('The Lord of the Rings: The Return of the King', '2003', 8.9, '377,845,905'),
#  ('Inception', '2010', 8.8, '292,576,195'),
#  ('The Lord of the Rings: The Fellowship of the Ring', '2001', 8.8, '315,544,750'),
#  ('The Lord of the Rings: The Two Towers', '2002', 8.7, '342,551,365'),
#  ('Hamilton', '2020', 8.6, None),
#  ('Gisaengchung', '2019', 8.6, '53,367,844'),
#  ('Soorarai Pottru', '2020', 8.6, None),
#  ('Interstellar', '2014', 8.6, '188,020,017'),
#  ('Cidade de Deus', '2002', 8.6, '7,563,397'),
#  ('Sen to Chihiro no kamikakushi', '2001', 8.6, '10,055,859'),
#  ('Joker', '2019', 8.5, '335,451,311'),
#  ('Whiplash', '2014', 8.5, '13,092,000'),
#  ('The Intouchables', '2011', 8.5, '13,182,281'),
#  ('The Prestige', '2006', 8.5, '53,089,891'),
#  ('The Departed', '2006', 8.5, '132,384,315'),
#  ('The Pianist', '2002', 8.5, '32,572,577'),
#  ('Capharnaüm', '2018', 8.4, '1,661,096'),
# ...

# %%
# %%sql
#    select Series_Title,Released_Year, IMDB_Rating,Gross from movie where Released_Year<2000;
# Out:
#  * sqlite:///database.db
# Done.
# [('The Shawshank Redemption', '1994', 9.3, '28,341,469'),
#  ('The Godfather', '1972', 9.2, '134,966,411'),
#  ('The Godfather: Part II', '1974', 9.0, '57,300,000'),
#  ('12 Angry Men', '1957', 9.0, '4,360,000'),
#  ('Pulp Fiction', '1994', 8.9, '107,928,762'),
#  ("Schindler's List", '1993', 8.9, '96,898,818'),
#  ('Fight Club', '1999', 8.8, '37,030,102'),
#  ('Forrest Gump', '1994', 8.8, '330,252,182'),
#  ('Il buono, il brutto, il cattivo', '1966', 8.8, '6,100,000'),
#  ('The Matrix', '1999', 8.7, '171,479,930'),
#  ('Goodfellas', '1990', 8.7, '46,836,394'),
#  ('Star Wars: Episode V - The Empire Strikes Back', '1980', 8.7, '290,475,067'),
#  ("One Flew Over the Cuckoo's Nest", '1975', 8.7, '112,000,000'),
#  ('Saving Private Ryan', '1998', 8.6, '216,540,909'),
#  ('The Green Mile', '1999', 8.6, '136,801,374'),
#  ('La vita è bella', '1997', 8.6, '57,598,247'),
#  ('Se7en', '1995', 8.6, '100,125,643'),
# ...

# %%
# %%sql
#    select Series_Title,Released_Year, IMDB_Rating,min(Gross) from movie;
# Out:
#  * sqlite:///database.db
# Done.
# [('Cowboy Bebop: Tengoku no tobira', '2001', 7.9, '1,000,045')]

# %%
# %%sql
#    select Series_Title,Released_Year, IMDB_Rating,Gross from movie where Gross>800000;
# Out:
#  * sqlite:///database.db
# Done.
# [("Schindler's List", '1993', 8.9, '96,898,818'),
#  ('Avengers: Endgame', '2019', 8.4, '858,373,000'),
#  ('Apocalypse Now', '1979', 8.4, '83,471,511'),
#  ('Bacheha-Ye aseman', '1997', 8.3, '933,933'),
#  ('Aliens', '1986', 8.3, '85,160,248'),
#  ('Chhichhore', '2019', 8.2, '898,575'),
#  ('Green Book', '2018', 8.2, '85,080,171'),
#  ('Die Hard', '1988', 8.2, '83,008,852'),
#  ('Rashômon', '1950', 8.2, '96,568'),
#  ('Sherlock Jr.', '1924', 8.2, '977,375'),
#  ('Haider', '2014', 8.1, '901,610'),
#  ('OMG: Oh My God!', '2012', 8.1, '923,221'),
#  ('Song of the Sea', '2014', 8.1, '857,524'),
#  ('Dead Poets Society', '1989', 8.1, '95,860,116'),
#  ('On the Waterfront', '1954', 8.1, '9,600,000'),
#  ('Mr. Smith Goes to Washington', '1939', 8.1, '9,600,000'),
#  ('The Imitation Game', '2014', 8.0, '91,125,683'),
#  ('Blade Runner 2049', '2017', 8.0, '92,054,159'),
#  ('Young Frankenstein', '1974', 8.0, '86,300,000'),
# ...

# %%
# %%sql
#    select Series_Title,Released_Year, IMDB_Rating,Gross from movie where IMDB_Rating>8;
# Out:
#  * sqlite:///database.db
# Done.
# [('The Shawshank Redemption', '1994', 9.3, '28,341,469'),
#  ('The Godfather', '1972', 9.2, '134,966,411'),
#  ('The Dark Knight', '2008', 9.0, '534,858,444'),
#  ('The Godfather: Part II', '1974', 9.0, '57,300,000'),
#  ('12 Angry Men', '1957', 9.0, '4,360,000'),
#  ('The Lord of the Rings: The Return of the King', '2003', 8.9, '377,845,905'),
#  ('Pulp Fiction', '1994', 8.9, '107,928,762'),
#  ("Schindler's List", '1993', 8.9, '96,898,818'),
#  ('Inception', '2010', 8.8, '292,576,195'),
#  ('Fight Club', '1999', 8.8, '37,030,102'),
#  ('The Lord of the Rings: The Fellowship of the Ring', '2001', 8.8, '315,544,750'),
#  ('Forrest Gump', '1994', 8.8, '330,252,182'),
#  ('Il buono, il brutto, il cattivo', '1966', 8.8, '6,100,000'),
#  ('The Lord of the Rings: The Two Towers', '2002', 8.7, '342,551,365'),
#  ('The Matrix', '1999', 8.7, '171,479,930'),
#  ('Goodfellas', '1990', 8.7, '46,836,394'),
# ...
